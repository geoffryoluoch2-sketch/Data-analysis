# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv(r'c:\Users\backupadmin\Desktop\sales_data_sample.csv', encoding='cp1252')

# %%
df.shape
# Out:
# (2823, 25)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   str
#  6   STATUS            2823 non-null   str
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   str
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   str
#  13  CUSTOMERNAME      2823 non-null   str
#  14  PHONE             2823 non-null   str
#  15  ADDRESSLINE1      2823 non-null   str
#  16  ADDRESSLINE2      302 non-null    str
# ...

# %%
(df['COUNTRY'] == 'USA').value_counts()
# Out:
# COUNTRY
# False    1819
# True     1004
# Name: count, dtype: int64

# %%
df.head(7)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
# 5        10168               36      96.66                1  3479.76
# 6        10180               29      86.13                9  2497.77
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
# ...

# %%
df['CONTACTFULLNAME'] = (df['CONTACTLASTNAME'] + ' ' + df['CONTACTFIRSTNAME'])
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...          NaN
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...          NaN
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...          NaN
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...          NaN
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...          NaN
#
#             CITY STATE POSTALCODE COUNTRY TERRITORY CONTACTLASTNAME  \
# ...

# %%
df.drop(columns= ['CONTACTLASTNAME', 'CONTACTFIRSTNAME'], inplace=True)
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...             PHONE  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...        2125557818
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...        26.47.1555
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...  +33 1 46 62 7555
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...        6265557265
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...        6505551386
#
#                     ADDRESSLINE1 ADDRESSLINE2           CITY STATE POSTALCODE  \
# ...

# %%
df.drop(columns= ['STATUS','ORDERDATE','ORDERLINENUMBER','ORDERNUMBER','YEAR_ID','PHONE','ADDRESSLINE1','ADDRESSLINE2','POSTALCODE','TERRITORY'], inplace=True)
df.head()
# Out:
#    QUANTITYORDERED  PRICEEACH    SALES  QTR_ID  MONTH_ID  PRODUCTLINE  MSRP  \
# 0               30      95.70  2871.00       1         2  Motorcycles    95
# 1               34      81.35  2765.90       2         5  Motorcycles    95
# 2               41      94.74  3884.34       3         7  Motorcycles    95
# 3               45      83.26  3746.70       3         8  Motorcycles    95
# 4               49     100.00  5205.27       4        10  Motorcycles    95
#
#   PRODUCTCODE              CUSTOMERNAME           CITY STATE COUNTRY DEALSIZE  \
# 0    S10_1678         Land of Toys Inc.            NYC    NY     USA    Small
# 1    S10_1678        Reims Collectables          Reims   NaN  France    Small
# 2    S10_1678           Lyon Souveniers          Paris   NaN  France   Medium
# 3    S10_1678         Toys4GrownUps.com       Pasadena    CA     USA   Medium
# 4    S10_1678  Corporate Gift Ideas Co.  San Francisco    CA     USA   Medium
#
#    CONTACTFULLNAME
# 0          Yu Kwai
# ...

# %%
df.shape
# Out:
# (2823, 14)

# %%
mean_value = df['SALES'].mean().round(2)
mean_value
# Out:
# np.float64(3553.89)

# %%
sales_by_country = df.groupby('COUNTRY')['SALES'].sum().sort_values(ascending=False).head(10)
sales_by_country
# Out:
# COUNTRY
# USA          3627982.83
# Spain        1215686.92
# France       1110916.52
# Australia     630623.10
# UK            478880.46
# Italy         374674.31
# Finland       329581.91
# Norway        307463.70
# Singapore     288488.41
# Denmark       245637.15
# Name: SALES, dtype: float64

# %%
country_pct = ((sales_by_country/sales_by_country.sum()) * 100).round(2)
country_pct
# Out:
# COUNTRY
# USA          42.14
# Spain        14.12
# France       12.90
# Australia     7.32
# UK            5.56
# Italy         4.35
# Finland       3.83
# Norway        3.57
# Singapore     3.35
# Denmark       2.85
# Name: SALES, dtype: float64

# %%
total_sales = df['SALES'].sum()
total_sales
# Out:
# np.float64(10032628.85)

# %%
sales_by_country.plot(kind='barh'),
plt.xlabel('Sales'),
plt.ylabel('Country'),
plt.title('Sales Vs.Country')
plt.show()

# %%
customername_by_sales = df.groupby('CUSTOMERNAME')['SALES'].sum().sort_values(ascending=False).head(10)
customername_by_sales
# Out:
# CUSTOMERNAME
# Euro Shopping Channel           912294.11
# Mini Gifts Distributors Ltd.    654858.06
# Australian Collectors, Co.      200995.41
# Muscle Machine Inc              197736.94
# La Rochelle Gifts               180124.90
# Dragon Souveniers, Ltd.         172989.68
# Land of Toys Inc.               164069.44
# The Sharp Gifts Warehouse       160010.27
# AV Stores, Co.                  157807.81
# Anna's Decorations, Ltd         153996.13
# Name: SALES, dtype: float64

# %%
plt.figure()
plt.barh(customername_by_sales.index, customername_by_sales.values, color='green', label='customername')
plt.title('Top 10 Customernames by Total sales')
plt.xlabel('Total Sales')
plt.ylabel('customername')
plt.show()

# %%
df['SALES'].describe()
# Out:
# count     2823.000000
# mean      3553.889072
# std       1841.865106
# min        482.130000
# 25%       2203.430000
# 50%       3184.800000
# 75%       4508.000000
# max      14082.800000
# Name: SALES, dtype: float64

# %%
top_sales = df['SALES'].sort_values(ascending=False).head(10)
top_sales
# Out:
# 598     14082.8
# 744     12536.5
# 53      12001.0
# 1062    11887.8
# 104     11886.6
# 1995    11739.7
# 44      11623.7
# 1133    11336.7
# 188     11279.2
# 30      10993.5
# Name: SALES, dtype: float64

# %%
sales_by_country
# Out:
# COUNTRY
# USA          3627982.83
# Spain        1215686.92
# France       1110916.52
# Australia     630623.10
# UK            478880.46
# Italy         374674.31
# Finland       329581.91
# Norway        307463.70
# Singapore     288488.41
# Denmark       245637.15
# Name: SALES, dtype: float64

# %%
sales_by_city = df.groupby('CITY')['SALES'].sum().sort_values(ascending=False).head(17)
sales_by_city
# Out:
# CITY
# Madrid           1082551.44
# San Rafael        654858.06
# NYC               560787.77
# Singapore         288488.41
# Paris             268944.68
# San Francisco     224358.68
# New Bedford       207874.86
# Nantes            204304.86
# Melbourne         200995.41
# Brickhaven        165255.20
# San Jose          160010.27
# Manchester        157807.81
# Boston            154069.66
# North Sydney      153996.13
# Chatswood         151570.98
# Philadelphia      151189.13
# Salzburg          149798.63
# Name: SALES, dtype: float64

# %%
sales_by_city.sum()
# Out:
# np.float64(4936861.9799999995)

# %%
deficit = total_sales - sales_by_city.sum()
deficit
# Out:
# np.float64(5095766.87)

# %%
sales_productline = df.groupby('PRODUCTLINE')['SALES'].sum().sort_values(ascending=False).head(7)
sales_productline
# Out:
# PRODUCTLINE
# Classic Cars        3919615.66
# Vintage Cars        1903150.84
# Motorcycles         1166388.34
# Trucks and Buses    1127789.84
# Planes               975003.57
# Ships                714437.13
# Trains               226243.47
# Name: SALES, dtype: float64

# %%
sales_productline.sum()
# Out:
# np.float64(10032628.850000001)

# %%
df['CITY'].unique()
# Out:
# <StringArray>
# [           'NYC',          'Reims',          'Paris',       'Pasadena',
#   'San Francisco',     'Burlingame',          'Lille',         'Bergen',
#       'Melbourne',         'Newark',    'Bridgewater',         'Nantes',
#       'Cambridge',       'Helsinki',        'Stavern',      'Allentown',
#        'Salzburg',      'Chatswood',    'New Bedford',      'Liverpool',
#          'Madrid',           'Lule',      'Singapore', 'South Brisbane',
#    'Philadelphia',           'Lyon',      'Vancouver',        'Burbank',
#       'New Haven',      'Minato-ku',         'Torino',          'Boras',
#      'Versailles',     'San Rafael',         'Nashua',     'Brickhaven',
#    'North Sydney',       'Montreal',          'Osaka',   'White Plains',
#       'Kobenhavn',         'London',       'Toulouse',      'Barcelona',
#     'Los Angeles',      'San Diego',      'Bruxelles',      'Tsawassen',
#          'Boston',          'Cowes',           'Oulu',       'San Jose',
# ...

# %%
nyc_sales = df.loc[df['CITY'] == 'NYC', 'SALES']
nyc_sales.head(10).sort_values(ascending=False)
# Out:
# 91     7023.90
# 80     6065.55
# 99     5868.20
# 31     4860.24
# 19     4396.14
# 54     3896.49
# 73     3176.00
# 117    2910.40
# 0      2871.00
# 11     2333.12
# Name: SALES, dtype: float64

# %%
df['PRODUCTLINE'].unique()
# Out:
# <StringArray>
# [     'Motorcycles',     'Classic Cars', 'Trucks and Buses',
#      'Vintage Cars',           'Planes',            'Ships',
#            'Trains']
# Length: 7, dtype: str

# %%
Ships_sales = df.loc[df['PRODUCTLINE'] == 'Ships', 'SALES']
Ships_sales.head()
# Out:
# 935    3421.04
# 936    1878.66
# 937    3853.60
# 938    3442.64
# 939    3482.16
# Name: SALES, dtype: float64

# %%
Ships_sales.sum().round(2)
# Out:
# np.float64(714437.13)

# %%
Trains_sales = df.loc[df['PRODUCTLINE'] == 'Trains', 'SALES']
Trains_sales
# Out:
# 1065    4330.10
# 1066    2011.80
# 1067    4837.18
# 1068    2151.82
# 1069    2573.46
#          ...
# 2427    1623.25
# 2428    1405.92
# 2429    2282.28
# 2430    8977.05
# 2431    3256.35
# Name: SALES, Length: 77, dtype: float64

# %%
Trains_sales.sum()
# Out:
# np.float64(226243.47000000003)

# %%
plt.hist(df['SALES'], color='black'),
plt.xlabel('sales'),
plt.ylabel('frequency'),
plt.title('distribution of sales', color='purple'),
plt.show()

# %%
df['PRODUCTLINE'].nunique()
# Out:
# 7

# %%
explode = [0.2] + [1] * (len(sales_productline) - 1)

# %%
sales_productline.plot(kind='pie',explode=explode, autopct='%1.1f%%', startangle=90, shadow=True)
plt.title('SALES BY PRODUCTLINE', color='red')
plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
df['PRICEEACH'].corr(df['SALES'])
# Out:
# np.float64(0.6578409283176879)

# %%
df['DEALSIZE'].unique()
# Out:
# <StringArray>
# ['Small', 'Medium', 'Large']
# Length: 3, dtype: str

# %%
dealsize_sales = df.groupby('DEALSIZE')['SALES'].sum().sort_values(ascending=False)
dealsize_sales
# Out:
# DEALSIZE
# Medium    6087432.24
# Small     2643077.35
# Large     1302119.26
# Name: SALES, dtype: float64

# %%
dealsize_sales_pct = round(dealsize_sales/total_sales * 100, 2)
dealsize_sales_pct
# Out:
# DEALSIZE
# Medium    60.68
# Small     26.34
# Large     12.98
# Name: SALES, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   QUANTITYORDERED  2823 non-null   int64
#  1   PRICEEACH        2823 non-null   float64
#  2   SALES            2823 non-null   float64
#  3   QTR_ID           2823 non-null   int64
#  4   MONTH_ID         2823 non-null   int64
#  5   PRODUCTLINE      2823 non-null   str
#  6   MSRP             2823 non-null   int64
#  7   PRODUCTCODE      2823 non-null   str
#  8   CUSTOMERNAME     2823 non-null   str
#  9   CITY             2823 non-null   str
#  10  STATE            1337 non-null   str
#  11  COUNTRY          2823 non-null   str
#  12  DEALSIZE         2823 non-null   str
#  13  CONTACTFULLNAME  2823 non-null   str
# dtypes: float64(2), int64(4), str(8)
# memory usage: 308.9 KB

# %%
sales_by_qtr_id = df.groupby('QTR_ID')['SALES'].sum().sort_values(ascending=False).head()
sales_by_qtr_id
# Out:
# QTR_ID
# 4    3874780.01
# 1    2350817.73
# 2    2048120.30
# 3    1758910.81
# Name: SALES, dtype: float64

# %%
df.rename(columns={'MONTH_ID':'MONTHS'}, inplace=True)
df.head()
# Out:
#    QUANTITYORDERED  PRICEEACH    SALES  QTR_ID  MONTHS  PRODUCTLINE  MSRP  \
# 0               30      95.70  2871.00       1       2  Motorcycles    95
# 1               34      81.35  2765.90       2       5  Motorcycles    95
# 2               41      94.74  3884.34       3       7  Motorcycles    95
# 3               45      83.26  3746.70       3       8  Motorcycles    95
# 4               49     100.00  5205.27       4      10  Motorcycles    95
#
#   PRODUCTCODE              CUSTOMERNAME           CITY STATE COUNTRY DEALSIZE  \
# 0    S10_1678         Land of Toys Inc.            NYC    NY     USA    Small
# 1    S10_1678        Reims Collectables          Reims   NaN  France    Small
# 2    S10_1678           Lyon Souveniers          Paris   NaN  France   Medium
# 3    S10_1678         Toys4GrownUps.com       Pasadena    CA     USA   Medium
# 4    S10_1678  Corporate Gift Ideas Co.  San Francisco    CA     USA   Medium
#
#    CONTACTFULLNAME
# 0          Yu Kwai
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   QUANTITYORDERED  2823 non-null   int64
#  1   PRICEEACH        2823 non-null   float64
#  2   SALES            2823 non-null   float64
#  3   QTR_ID           2823 non-null   int64
#  4   MONTHS           2823 non-null   int64
#  5   PRODUCTLINE      2823 non-null   str
#  6   MSRP             2823 non-null   int64
#  7   PRODUCTCODE      2823 non-null   str
#  8   CUSTOMERNAME     2823 non-null   str
#  9   CITY             2823 non-null   str
#  10  STATE            1337 non-null   str
#  11  COUNTRY          2823 non-null   str
#  12  DEALSIZE         2823 non-null   str
#  13  CONTACTFULLNAME  2823 non-null   str
# dtypes: float64(2), int64(4), str(8)
# memory usage: 308.9 KB

# %%
plt.scatter(x=df['QUANTITYORDERED'], y=df['SALES'], color='green'),
plt.xlabel('price of each product'),
plt.ylabel('sales'),
plt.title('relationship', color='red'),
plt.show()
